# %% [markdown]
# [Home](../../README.md)
#
# ### Model Training - Linear Regression
#
# We will next train a multiple feature linear regression machine learning model.

# %% [markdown]
# #### Step 1
#
# Load the required dependencies:

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Step 2
#
# Store the data columns for Linear Regression.

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('2.3.2.training_data.csv')

x_name = ['BMI', 'Age', 'BP']
y_name = 'Target'

x = np.array(training_data[x_name].values)
y = training_data[y_name].values

print(x)
# Out:
# [[2.40000000e+01 6.10000000e+01 4.08450704e-01]
#  [3.05000000e+01 3.20000000e+01 3.80281690e-01]
#  [2.92000000e+01 3.40000000e+01 1.54929577e-01]
#  [2.98000000e+01 6.70000000e+01 2.53521127e-01]
#  [3.01000000e+01 5.70000000e+01 7.74647887e-01]
#  [2.31000000e+01 4.10000000e+01 3.38028169e-01]
#  [2.55000000e+01 3.40000000e+01 4.36619718e-01]
#  [2.26000000e+01 5.40000000e+01 3.94366197e-01]
#  [2.40000000e+01 5.20000000e+01 2.95774648e-01]
#  [2.26000000e+01 2.70000000e+01 1.26760563e-01]
#  [2.03000000e+01 3.70000000e+01 2.95774648e-01]
#  [2.10000000e+01 2.90000000e+01 1.26760563e-01]
#  [2.68000000e+01 4.30000000e+01 8.59154930e-01]
#  [3.20000000e+01 4.50000000e+01 6.76056338e-01]
#  [2.92000000e+01 4.20000000e+01 4.36619718e-01]
#  [2.80000000e+01 6.60000000e+01 5.49295775e-01]
#  [2.59000000e+01 6.80000000e+01 4.36619718e-01]
#  [2.53000000e+01 3.30000000e+01 3.23943662e-01]
#  [2.96000000e+01 6.90000000e+01 8.45070423e-01]
#  [2.12000000e+01 3.40000000e+01 3.09859155e-01]
#  [2.21000000e+01 2.80000000e+01 2.81690141e-01]
#  [3.00000000e+01 2.90000000e+01 3.23943662e-01]
#  [2.54000000e+01 4.40000000e+01 4.64788732e-01]
#  [2.17000000e+01 5.70000000e+01 4.50704225e-01]
#  [3.38000000e+01 4.10000000e+01 8.63802817e-01]
#  [3.19000000e+01 4.20000000e+01 2.95774648e-01]
#  [3.61000000e+01 5.70000000e+01 7.74647887e-01]
#  [3.46000000e+01 4.10000000e+01 3.56760563e-01]
#  [2.45000000e+01 5.20000000e+01 3.94366197e-01]
#  [2.16000000e+01 4.80000000e+01 3.52112676e-01]
#  [2.86000000e+01 5.30000000e+01 3.66197183e-01]
#  [2.28000000e+01 3.60000000e+01 3.52112676e-01]
#  [2.65000000e+01 5.30000000e+01 4.92957746e-01]
#  [2.41000000e+01 5.30000000e+01 6.05633803e-01]
#  [3.03000000e+01 4.70000000e+01 6.61971831e-01]
#  [2.18000000e+01 3.70000000e+01 3.09859155e-01]
#  [2.22000000e+01 6.00000000e+01 6.00985915e-01]
#  [3.43000000e+01 6.90000000e+01 7.18309859e-01]
#  [2.97000000e+01 3.10000000e+01 3.66197183e-01]
#  [1.96000000e+01 2.70000000e+01 2.25352113e-01]
#  [3.18000000e+01 5.00000000e+01 2.81690141e-01]
#  [3.12000000e+01 7.50000000e+01 7.84084507e-01]
#  [1.95000000e+01 3.30000000e+01 2.53521127e-01]
#  [2.68000000e+01 5.40000000e+01 3.52112676e-01]
#  [2.02000000e+01 3.70000000e+01 2.67605634e-01]
#  [3.10000000e+01 5.60000000e+01 2.34788732e-01]
#  [1.98000000e+01 4.90000000e+01 3.66197183e-01]
#  [2.21000000e+01 4.30000000e+01 5.63380282e-02]
#  [2.03000000e+01 4.50000000e+01 1.73661972e-01]
#  [2.87000000e+01 3.50000000e+01 4.92957746e-01]
#  [2.07000000e+01 6.70000000e+01 2.95774648e-01]
#  [3.83000000e+01 3.70000000e+01 7.18309859e-01]
#  [2.49000000e+01 4.60000000e+01 7.46478873e-01]
#  [3.04000000e+01 4.70000000e+01 8.16901408e-01]
#  [2.21000000e+01 4.20000000e+01 3.23943662e-01]
#  [2.81000000e+01 5.80000000e+01 6.90140845e-01]
#  [2.49000000e+01 4.20000000e+01 4.08450704e-01]
#  [2.46000000e+01 6.10000000e+01 5.49295775e-01]
#  [2.58000000e+01 6.10000000e+01 5.07042254e-01]
#  [2.06000000e+01 3.40000000e+01 3.52112676e-01]
#  [2.79000000e+01 5.10000000e+01 4.78873239e-01]
#  [2.81000000e+01 4.30000000e+01 8.30985915e-01]
#  [3.43000000e+01 4.30000000e+01 3.09859155e-01]
#  [3.30000000e+01 3.40000000e+01 1.54929577e-01]
#  [3.70000000e+01 6.90000000e+01 5.77464789e-01]
#  [2.95000000e+01 5.20000000e+01 5.96197183e-01]
#  [2.02000000e+01 4.10000000e+01 0.00000000e+00]
#  [3.24000000e+01 4.70000000e+01 6.05633803e-01]
#  [2.68000000e+01 5.40000000e+01 6.47887324e-01]
#  [2.54000000e+01 3.80000000e+01 3.09859155e-01]
#  [3.50000000e+01 3.30000000e+01 3.80281690e-01]
#  [2.30000000e+01 5.20000000e+01 6.33802817e-01]
#  [2.04000000e+01 4.80000000e+01 5.07042254e-01]
#  [2.13000000e+01 3.00000000e+01 3.52112676e-01]]

# %% [markdown]
# #### Step 3
#
# Plot the feature `x` and target `y` data on a graph using the column headings as the graph labels.

# %%
# Plot the data points
for col in x_name:
    plt.scatter(training_data[col], training_data[y_name], marker='x')
# Set the title
plt.title("Diabetes Disease Progress")
# Set the y-axis label
plt.ylabel(f'Training {training_data[y_name].name}')
# Set the x-axis label
plt.xlabel(f'Training {*x_name,}')
plt.show()

# %% [markdown]
# #### Step 4
#
# Use the [Scikit-learn](https://scikit-learn.org/stable/) library to instantiate a Machine Learning model class and store it in the `my_model` variable as an object.

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Step 5
#
# Plot the features, targets and model (linear regression).

# %%
y_pred = my_model.predict(x)
plt.plot(x, y_pred)
for col in x_name:
    plt.scatter(training_data[col], training_data[y_name], marker='x')
plt.title("Diabetes Disease Progress")
plt.ylabel(f'Training {training_data[y_name].name}')
plt.xlabel(f'Training {*x_name,}')
plt.show()

# %%
my_model.predict([[30, 50]])
# Out:
# array([185.79312338])
